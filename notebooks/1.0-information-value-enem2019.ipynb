# %% [markdown]
# # Information Value ENEM2019

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd
import os 
import numpy as np 
import seaborn as sns
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib as mpl

pd.set_option('display.max_columns', None)
sns.set_palette('Paired')
sns.set_style("whitegrid")
plt.rcParams['axes.facecolor'] = 'white'
mpl.rcParams['font.size'] = 14

# %% [markdown]
# ## 2. Reading Data

# %%
processed_directory = sorted(filter(lambda dir: '.parquet' in dir, os.listdir('../data/processed')), reverse = True)[0]
processed_directory = '../data/processed/' + processed_directory

data = pd.read_parquet(processed_directory).query('enem_year == 2019')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50873 entries, 54823 to 105695
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           50873 non-null  int64
#  1   enem_year                    50873 non-null  int64
#  2   age                          50873 non-null  object
#  3   sex                          50873 non-null  object
#  4   marital_status               50873 non-null  object
#  5   color_race                   50873 non-null  object
#  6   high_school_status           50873 non-null  object
#  7   year_completion_high_school  50873 non-null  int64
#  8   school_type                  50873 non-null  object
#  9   id_city_school               11461 non-null  float64
#  10  city_school                  11461 non-null  object
#  11  state_school                 11461 non-null  object
#  12  id_city_test                 50873 non-null  int64
#  13  city_test                    50873 non-null  object
#  14  state_test                   50873 non-null  object
#  15  presence_day_1               50873 non-null  float64
#  16  presence_day_2               50873 non-null  float64
#  17  nature_science_score         36973 non-null  float64
#  18  human_sciences_score         39139 non-null  float64
#  19  languages_codes_score        39139 non-null  float64
#  20  mathematics_score            36973 non-null  float64
#  21  ortography_score             39139 non-null  float64
#  22  understanding_score          39139 non-null  float64
#  23  structuring_score            39139 non-null  float64
#  24  argumentation_score          39139 non-null  float64
#  25  proposal_score               39139 non-null  float64
#  26  redaction_score              39139 non-null  float64
#  27  father_schooling             50873 non-null  object
#  28  mother_schooling             50873 non-null  object
#  29  father_profession_group      50873 non-null  object
#  30  mother_profession_group      50873 non-null  object
#  31  family_members               50873 non-null  float64
#  32  family_income                50873 non-null  object
#  33  bedrooms_qty                 50873 non-null  object
#  34  cars_qty                     50873 non-null  object
#  35  television_qty               50873 non-null  object
#  36  phones_qty                   50873 non-null  object
#  37  computer_qty                 50873 non-null  object
#  38  internet_access              50873 non-null  object
# dtypes: float64(14), int64(4), object(21)
# memory usage: 15.5+ MB

# %%
cities = pd.read_csv('../data/external/cities.csv', sep = ';', usecols = ['ibge_code', 'lat_city', 'long_city', 'capital', 'state_lat', 'state_long', 'region'])
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ibge_code   5570 non-null   int64
#  1   lat_city    5570 non-null   float64
#  2   long_city   5570 non-null   float64
#  3   capital     5570 non-null   int64
#  4   state_lat   5570 non-null   float64
#  5   state_long  5570 non-null   float64
#  6   region      5570 non-null   object
# dtypes: float64(4), int64(2), object(1)
# memory usage: 304.7+ KB

# %%
# Joining the candidates data and cities info
data = data.merge(cities, left_on = 'id_city_test', right_on = 'ibge_code')

# %%
# filter out candidates that failed in ENEM in one of the two days
# each presence day has value 1 then (presence_day_1 + presence_day_2) is equal 2
present_candidates = data.query('(presence_day_1 + presence_day_2) == 2')
present_candidates.head(5)
# Out:
#              id  enem_year                     age sex marital_status  \
# 0  190001004687       2019            18 years-old   F         Single
# 1  190001007110       2019            18 years-old   F         Single
# 2  190001007346       2019            20 years-old   F         Single
# 4  190001007985       2019  Less than 17 years-old   M         Single
# 5  190001009480       2019  Less than 17 years-old   F         Single
#
#   color_race                            high_school_status  \
# 0      Brown                         Completed High School
# 1      White                      Ends in the current year
# 2      White                         Completed High School
# 4      Brown  Will complete High School the following year
# 5      White  Will complete High School the following year
#
#    year_completion_high_school school_type  id_city_school city_school  \
# 0                            1     Unknown             NaN        None
# 1                            0      Public       1500800.0  Ananindeua
# 2                            3     Unknown             NaN        None
# 4                            0     Unknown             NaN        None
# 5                            0     Unknown             NaN        None
#
#   state_school  id_city_test   city_test state_test  presence_day_1  \
# 0         None       1500800  Ananindeua         PA             1.0
# 1           PA       1500800  Ananindeua         PA             1.0
# 2         None       1500800  Ananindeua         PA             1.0
# 4         None       1500800  Ananindeua         PA             1.0
# 5         None       1500800  Ananindeua         PA             1.0
#
#    presence_day_2  nature_science_score  human_sciences_score  \
# 0             1.0                 349.8                 417.1
# 1             1.0                 524.5                 544.7
# 2             1.0                 521.4                 514.7
# 4             1.0                 598.0                 613.6
# 5             1.0                 527.1                 705.7
#
#    languages_codes_score  mathematics_score  ortography_score  \
# 0                  416.6              468.3             120.0
# 1                  545.4              458.1             160.0
# 2                  615.5              699.8             120.0
# 4                  592.0              709.7             160.0
# 5                  656.8              603.3             160.0
#
#    understanding_score  structuring_score  argumentation_score  \
# 0                 40.0               40.0                120.0
# 1                120.0              140.0                140.0
# 2                120.0              140.0                160.0
# 4                200.0              160.0                160.0
# 5                120.0              140.0                180.0
#
#    proposal_score  redaction_score             father_schooling  \
# 0             0.0            320.0  Completed Elementary School
# 1           140.0            700.0        Completed High School
# 2           140.0            680.0  Completed Elementary School
# 4           200.0            880.0        Completed High School
# 5           140.0            740.0        Completed High School
#
#                     mother_schooling father_profession_group  \
# 0        Completed Elementary School                 Group C
# 1  Didn't complete Elementary School                 Group F
# 2                  Completed College                 Group C
# 4              Completed High School                 Group D
# 5              Completed High School                 Group B
#
#   mother_profession_group  family_members                family_income  \
# 0                 Group B             4.0     Less than 1 minimum wage
# 1                 Group F             6.0  Between 1-1.5 minimum wages
# 2                 Group D             4.0    Between 8-9 minimum wages
# 4                 Group D             5.0    Between 3-4 minimum wages
# 5                 Group B             4.0     Less than 1 minimum wage
#
#   bedrooms_qty cars_qty television_qty    phones_qty computer_qty  \
# 0          Two       No            One            No           No
# 1          Two       No            One  Four or more          One
# 2        Three       No          Three         Three          One
# 4        Three      One            One         Three          Two
# 5          One       No            One            No           No
#
#   internet_access  ibge_code  lat_city  long_city  capital  state_lat  \
# 0              No    1500800  -1.36391   -48.3743        0      -3.79
# 1             Yes    1500800  -1.36391   -48.3743        0      -3.79
# 2             Yes    1500800  -1.36391   -48.3743        0      -3.79
# 4              No    1500800  -1.36391   -48.3743        0      -3.79
# 5              No    1500800  -1.36391   -48.3743        0      -3.79
#
#    state_long region
# 0      -52.48  Norte
# 1      -52.48  Norte
# 2      -52.48  Norte
# 4      -52.48  Norte
# 5      -52.48  Norte

# %% [markdown]
# ## 2.1 Building proxy variable (Target)

# %%
present_candidates['approved'] = np.where(present_candidates.mathematics_score >= present_candidates.mathematics_score.quantile(0.90), 1, 0)
present_candidates.iloc[:, -5:]
# Out:
# /tmp/ipykernel_18550/2426088829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   present_candidates['approved'] = np.where(present_candidates.mathematics_score >= present_candidates.mathematics_score.quantile(0.90), 1, 0)
#        capital  state_lat  state_long        region  approved
# 0            0      -3.79      -52.48         Norte         0
# 1            0      -3.79      -52.48         Norte         0
# 2            0      -3.79      -52.48         Norte         1
# 4            0      -3.79      -52.48         Norte         1
# 5            0      -3.79      -52.48         Norte         0
# ...        ...        ...         ...           ...       ...
# 50866        0      -3.47      -65.10         Norte         0
# 50869        0      -8.38      -37.86      Nordeste         0
# 50870        0       1.99      -61.33         Norte         0
# 50871        0       1.99      -61.33         Norte         0
# 50872        0     -12.64      -55.42  Centro-Oeste         0
#
# [36926 rows x 5 columns]

# %% [markdown]
# ## 3. Information Value

# %% [markdown]
# Weight of evidence (WOE) and Information value (IV) are simple, yet powerful techniques to perform variable transformation and selection. These concepts have huge connection with the logistic regression modeling technique.
#
# <br>
# <img width="14%" src="https://miro.medium.com/max/768/1*6Aw782wiyiFtzvK7EOY8CA.png">
# <br><br>
# <img width="23%" src="https://miro.medium.com/max/1200/1*9Gi0fGyTpxfwM2TpV4GZQQ.png">
# <br><br>
# <img width="23%" src="https://miro.medium.com/max/1156/1*5S_5aAHWe0_knDGZUK3W8w.png">
# <br><br>
#
# Observations:
# * Each category (bin) should have at least 5% of the observations.
# * Each category (bin) should be non-zero for both non-events and events.
# * The WOE should be distinct for each category. Similar groups should be aggregated.
# * The WOE should be monotonic, i.e. either growing or decreasing with the groupings.
# * Missing values are binned separately.
#
# References:
# * https://sundarstyles89.medium.com/weight-of-evidence-and-information-value-using-python-6f05072e83eb
# * https://www.listendata.com/2015/03/weight-of-evidence-woe-and-information.html

# %%
def information_value(var, df = present_candidates):
    ''' 
    Function to calculate the information value of a variable
    '''
    
    df_iv = df.groupby(var).size().to_frame(name = '# count')
    df_iv['count%'] = df_iv['# count'] / df_iv['# count'].sum()
    df_iv['# Approved'] = df.groupby(var).approved.sum()
    df_iv['# Non Approved'] = df_iv['# count'] - df_iv['# Approved']
    df_iv['Approved%'] = df_iv['# Approved'] / df_iv['# count'] 
    df_iv['Non Approved%'] = df_iv['# Non Approved'] / df_iv['# count'] 
    df_iv['Approved% - Non Approved%'] = df_iv['Approved%'] - df_iv['Non Approved%']
    df_iv['Approved% / Non Approved%'] = df_iv['Approved%'] / df_iv['Non Approved%']
    df_iv['WOE'] = np.log(df_iv['Approved% / Non Approved%'])
    df_iv['IV'] = df_iv['Approved% - Non Approved%'] * df_iv['WOE']

    return df_iv, df_iv.IV.sum()

# %% [markdown]
# ## 3.1 Feature Selection

# %%
features_candidates = present_candidates[[
    'age', 
    'sex', 
    'marital_status', 
    'color_race', 
    'high_school_status', 
    'year_completion_high_school', 
    'school_type', 
    'state_test', 
    'father_schooling', 
    'mother_schooling', 
    'father_profession_group', 
    'mother_profession_group',
    'family_income',
    'region'
]]

features_candidates.head(5)
# Out:
#                       age sex marital_status color_race  \
# 0            18 years-old   F         Single      Brown
# 1            18 years-old   F         Single      White
# 2            20 years-old   F         Single      White
# 4  Less than 17 years-old   M         Single      Brown
# 5  Less than 17 years-old   F         Single      White
#
#                              high_school_status  year_completion_high_school  \
# 0                         Completed High School                            1
# 1                      Ends in the current year                            0
# 2                         Completed High School                            3
# 4  Will complete High School the following year                            0
# 5  Will complete High School the following year                            0
#
#   school_type state_test             father_schooling  \
# 0     Unknown         PA  Completed Elementary School
# 1      Public         PA        Completed High School
# 2     Unknown         PA  Completed Elementary School
# 4     Unknown         PA        Completed High School
# 5     Unknown         PA        Completed High School
#
#                     mother_schooling father_profession_group  \
# 0        Completed Elementary School                 Group C
# 1  Didn't complete Elementary School                 Group F
# 2                  Completed College                 Group C
# 4              Completed High School                 Group D
# 5              Completed High School                 Group B
#
#   mother_profession_group                family_income region
# 0                 Group B     Less than 1 minimum wage  Norte
# 1                 Group F  Between 1-1.5 minimum wages  Norte
# 2                 Group D    Between 8-9 minimum wages  Norte
# 4                 Group D    Between 3-4 minimum wages  Norte
# 5                 Group B     Less than 1 minimum wage  Norte

# %%
features_candidates.columns.to_series() \
    .apply(lambda x: information_value(x)[1]) \
        .to_frame(name = 'information_value') \
            .sort_values('information_value', ascending = False)
# Out:
#                              information_value
# state_test                           58.962559
# age                                  42.309531
# year_completion_high_school          26.266117
# family_income                        19.988589
# mother_schooling                     16.079464
# father_schooling                     13.903074
# marital_status                       12.311869
# color_race                           11.876382
# father_profession_group              11.616379
# mother_profession_group              10.742793
# region                                9.701394
# high_school_status                    8.146436
# school_type                           4.591559
# sex                                   3.495821

# %% [markdown]
# ### 3.7.1 State

# %%
state_test_iv_df, state_test_iv = information_value('state_test')
print('\nInformation Value (state_test_iv): ', state_test_iv, end = '\n\n')
state_test_iv_df
# Out:
# Information Value (state_test_iv):  58.96255914307033
#             # count    count%  # Approved  # Non Approved  Approved%  \
# state_test
# AC              282  0.007637           6             276   0.021277
# AL              659  0.017847          37             622   0.056146
# AM              758  0.020528          23             735   0.030343
# AP              323  0.008747           8             315   0.024768
# BA             2849  0.077154         182            2667   0.063882
# CE             2075  0.056193         195            1880   0.093976
# DF              602  0.016303         104             498   0.172757
# ES              682  0.018469          81             601   0.118768
# GO             1245  0.033716         109            1136   0.087550
# MA             1684  0.045605          55            1629   0.032660
# MG             3931  0.106456         533            3398   0.135589
# MS              473  0.012809          51             422   0.107822
# MT              622  0.016844          44             578   0.070740
# PA             2080  0.056329          81            1999   0.038942
# PB             1150  0.031143          89            1061   0.077391
# PE             2117  0.057331         177            1940   0.083609
# PI              897  0.024292          52             845   0.057971
# PR             1467  0.039728         201            1266   0.137014
# RJ             2530  0.068515         355            2175   0.140316
# RN              865  0.023425          78             787   0.090173
# RO              417  0.011293          15             402   0.035971
# RR               81  0.002194           4              77   0.049383
# RS             1555  0.042111         171            1384   0.109968
# SC              811  0.021963         117             694   0.144266
# SE              613  0.016601          36             577   0.058728
# SP             5834  0.157992         872            4962   0.149469
# TO              324  0.008774          16             308   0.049383
#
#             Non Approved%  Approved% - Non Approved%  \
# state_test
# AC               0.978723                  -0.957447
# AL               0.943854                  -0.887709
# AM               0.969657                  -0.939314
# AP               0.975232                  -0.950464
# BA               0.936118                  -0.872236
# CE               0.906024                  -0.812048
# DF               0.827243                  -0.654485
# ES               0.881232                  -0.762463
# GO               0.912450                  -0.824900
# MA               0.967340                  -0.934679
# MG               0.864411                  -0.728822
# MS               0.892178                  -0.784355
# MT               0.929260                  -0.858521
# PA               0.961058                  -0.922115
# PB               0.922609                  -0.845217
# PE               0.916391                  -0.832782
# PI               0.942029                  -0.884058
# PR               0.862986                  -0.725971
# RJ               0.859684                  -0.719368
# RN               0.909827                  -0.819653
# RO               0.964029                  -0.928058
# RR               0.950617                  -0.901235
# RS               0.890032                  -0.780064
# SC               0.855734                  -0.711467
# SE               0.941272                  -0.882545
# SP               0.850531                  -0.701063
# TO               0.950617                  -0.901235
#
#             Approved% / Non Approved%       WOE        IV
# state_test
# AC                           0.021739 -3.828641  3.665720
# AL                           0.059486 -2.822022  2.505133
# AM                           0.031293 -3.464376  3.254137
# AP                           0.025397 -3.673131  3.491180
# BA                           0.068241 -2.684703  2.341694
# CE                           0.103723 -2.266027  1.840124
# DF                           0.208835 -1.566209  1.025060
# ES                           0.134775 -2.004146  1.528088
# GO                           0.095951 -2.343921  1.933499
# MA                           0.033763 -3.388388  3.167057
# MG                           0.156857 -1.852421  1.350085
# MS                           0.120853 -2.113180  1.657483
# MT                           0.076125 -2.575384  2.211021
# PA                           0.040520 -3.205953  2.956259
# PB                           0.083883 -2.478331  2.094728
# PE                           0.091237 -2.394294  1.993925
# PI                           0.061538 -2.788093  2.464836
# PR                           0.158768 -1.840313  1.336014
# RJ                           0.163218 -1.812666  1.303973
# RN                           0.099111 -2.311519  1.894644
# RO                           0.037313 -3.288402  3.051826
# RR                           0.051948 -2.957511  2.665411
# RS                           0.123555 -2.091070  1.631169
# SC                           0.168588 -1.780298  1.266624
# SE                           0.062392 -2.774323  2.448465
# SP                           0.175736 -1.738775  1.218990
# TO                           0.051948 -2.957511  2.665411

# %% [markdown]
# ### 3.7.1 Family Income

# %%
# family_income label ordered

income_order = [
  'No income',
  'Less than 1 minimum wage',
  'Between 1-1.5 minimum wages',
  'Between 1.5-2 minimum wages',
  'Between 2-2.5 minimum wages',
  'Between 2.5-3 minimum wages',
  'Between 3-4 minimum wages',
  'Between 4-5 minimum wages',
  'Between 5-6 minimum wages',
  'Between 6-7 minimum wages',
  'Between 7-8 minimum wages',
  'Between 8-9 minimum wages',
  'Between 9-10 minimum wages',
  'Between 10-12 minimum wages',
  'Between 12-15 minimum wages',
  'Between 15-20 minimum wages',
  'More than 20 minimum wages'
]

# %%
family_income_iv_df, family_income_iv = information_value('family_income')
print('\nInformation Value (family_income_iv): ', family_income_iv, end = '\n\n')
family_income_iv_df
# Out:
# Information Value (family_income_iv):  19.9885888394243
#                              # count    count%  # Approved  # Non Approved  \
# family_income
# Between 1-1.5 minimum wages     9116  0.246872         345            8771
# Between 1.5-2 minimum wages     3590  0.097221         260            3330
# Between 10-12 minimum wages      478  0.012945         179             299
#                              Approved% / Non Approved%       WOE        IV
# age
# 17 years-old                                  0.137001 -1.987766  1.508741
# 18 years-old                                  0.120668 -2.114711  1.659308
# 19 years-old                                  0.110390 -2.203739  1.765569
# 20 years-old                                  0.111801 -2.191033  1.750378
# 21 years-old                                  0.105171 -2.252164  1.823519
# 22 years-old                                  0.092754 -2.377809  1.974149
# 23 years-old                                  0.064238 -2.745164  2.413766
# 24 years-old                                  0.091698 -2.389259  1.987885
# 25 years-old                                  0.087464 -2.436533  2.044597
# Between 26 and 30 years-old                   0.086080 -2.452482  2.063728
# Between 31 and 35 years-old                   0.068823 -2.676224  2.331574
# Between 36 and 40 years-old                   0.042806 -3.151073  2.892376
# Between 41 and 45 years-old                   0.046512 -3.068053  2.795337
# Between 46 and 50 years-old                   0.024845 -3.695110  3.515953
# Between 51 and 55 years-old                   0.038462 -3.258097  3.016756
# Between 56 and 60 years-old                   0.021978 -3.817712  3.653510
# Between 61 and 65 years-old                   0.111111 -2.197225  1.757780
# Between 66 and 70 years-old                   0.285714 -1.252763  0.695979
# Less than 17 years-old                        0.153038 -1.877071  1.378799
# More than 70 years-old                        0.166667 -1.791759  1.279828

# %%
color_race_iv_df, color_race_iv = information_value('color_race')
print('\nInformation Value (color_race): ', color_race_iv, end = '\n\n')
color_race_iv_df
# Out:
# Information Value (color_race):  11.87638244709725
#             # count    count%  # Approved  # Non Approved  Approved%  \
# color_race
# Black          4573  0.123842         170            4403   0.037175
# Brown         16712  0.452581        1055           15657   0.063128
# Indigenous      216  0.005850          12             204   0.055556
# Unknown         781  0.021150         107             674   0.137004
# White         13753  0.372448        2244           11509   0.163164
# Yellow          891  0.024129         104             787   0.116723
#
#             Non Approved%  Approved% - Non Approved%  \
# color_race
# Black            0.962825                  -0.925651
# Brown            0.936872                  -0.873743
# Indigenous       0.944444                  -0.888889
# Unknown          0.862996                  -0.725992
# White            0.836836                  -0.673671
# Yellow           0.883277                  -0.766554
#
#             Approved% / Non Approved%       WOE        IV
# color_race
# Black                        0.038610 -3.254243  3.012292
# Brown                        0.067382 -2.697377  2.356816
# Indigenous                   0.058824 -2.833213  2.518412
# Unknown                      0.158754 -1.840401  1.336117
# White                        0.194978 -1.634869  1.101364
# Yellow                       0.132147 -2.023837  1.551381

# %% [markdown]
# ### 3.7.4 Sex

# %%
sex_iv_df, sex_iv = information_value('sex')
print('\nInformation Value (sex): ', sex_iv, end = '\n\n')
sex_iv_df
# Out:
# Information Value (sex):  3.495821001581836
#      # count    count%  # Approved  # Non Approved  Approved%  Non Approved%  \
# sex
# F      21996  0.595678        1523           20473   0.069240       0.930760
# M      14930  0.404322        2169           12761   0.145278       0.854722
#
#      Approved% - Non Approved%  Approved% / Non Approved%       WOE        IV
# sex
# F                    -0.861520                   0.074391 -2.598425  2.238596
# M                    -0.709444                   0.169971 -1.772127  1.257225

# %% [markdown]
# ### 3.7.5 Features Candidates

# %%
features_candidates = data[[
    'age', 
    'sex', 
    'marital_status', 
    'color_race', 
    'high_school_status', 
    'year_completion_high_school', 
    'school_type', 
    'state_test', 
    'father_schooling', 
    'mother_schooling', 
    'father_profession_group', 
    'mother_profession_group',
    'family_income',
    'region'
]]

features_candidates
# Out:
#                                age sex marital_status color_race  \
# 0                     18 years-old   F         Single      Brown
# 1                     18 years-old   F         Single      White
# 2                     20 years-old   F         Single      White
# 3      Between 26 and 30 years-old   M         Single      Brown
# 4           Less than 17 years-old   M         Single      Brown
# ...                            ...  ..            ...        ...
# 50868                 18 years-old   M         Single      Black
# 50869       Less than 17 years-old   F         Single      Black
# 50870                 17 years-old   F         Single      Brown
# 50871                 22 years-old   M         Single      Brown
# 50872                 24 years-old   M         Single     Yellow
#
#                                  high_school_status  \
# 0                             Completed High School
# 1                          Ends in the current year
# 2                             Completed High School
# 3                             Completed High School
# 4      Will complete High School the following year
# ...                                             ...
# 50868                      Ends in the current year
# 50869  Will complete High School the following year
# 50870                      Ends in the current year
# 50871                         Completed High School
# 50872                         Completed High School
#
#        year_completion_high_school school_type state_test  \
# 0                                1     Unknown         PA
# 1                                0      Public         PA
# 2                                3     Unknown         PA
# 3                                1     Unknown         PA
# 4                                0     Unknown         PA
# ...                            ...         ...        ...
# 50868                            0      Public         RO
# 50869                            0     Unknown         PE
# 50870                            0      Public         RR
# 50871                            3     Unknown         RR
# 50872                            4     Unknown         MT
#
#                         father_schooling                   mother_schooling  \
# 0            Completed Elementary School        Completed Elementary School
# 1                  Completed High School  Didn't complete Elementary School
# 2            Completed Elementary School                  Completed College
# 3                  Completed High School        Completed Elementary School
# 4                  Completed High School              Completed High School
# ...                                  ...                                ...
# 50868                      Never studied        Completed Elementary School
# 50869                 Completed Graduate        Completed Elementary School
# 50870  Didn't complete Elementary School                  Completed College
# 50871                            Unknown              Completed High School
# 50872  Didn't complete Elementary School  Didn't complete Elementary School
#
#       father_profession_group mother_profession_group  \
# 0                     Group C                 Group B
# 1                     Group F                 Group F
# 2                     Group C                 Group D
# 3                     Group C                 Group B
# 4                     Group D                 Group D
# ...                       ...                     ...
# 50868                 Group A                 Group B
# 50869                 Group D                 Group C
# 50870                 Group C                 Group D
# 50871                 Group A                 Group B
# 50872                 Group A                 Group A
#
#                      family_income        region
# 0         Less than 1 minimum wage         Norte
# 1      Between 1-1.5 minimum wages         Norte
# 2        Between 8-9 minimum wages         Norte
# 3         Less than 1 minimum wage         Norte
# 4        Between 3-4 minimum wages         Norte
# ...                            ...           ...
# 50868     Less than 1 minimum wage         Norte
# 50869    Between 3-4 minimum wages      Nordeste
# 50870  Between 1.5-2 minimum wages         Norte
# 50871  Between 1.5-2 minimum wages         Norte
# 50872  Between 1-1.5 minimum wages  Centro-Oeste
#
# [50873 rows x 14 columns]

# %%
features_candidates.columns.to_series() \
    .apply(lambda x: information_value(x)[1]) \
        .to_frame(name = 'information_value') \
            .sort_values('information_value', ascending = False)
# Out:
#                              information_value
# state_test                           58.962559
# age                                  42.309531
# year_completion_high_school          26.266117
# family_income                        19.988589
# mother_schooling                     16.079464
# father_schooling                     13.903074
# marital_status                       12.311869
# color_race                           11.876382
# father_profession_group              11.616379
# mother_profession_group              10.742793
# region                                9.701394
# high_school_status                    8.146436
# school_type                           4.591559
# sex                                   3.495821
